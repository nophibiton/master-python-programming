# %%
sum([10,20,30])
# Out:
# 60

# %% [markdown]
# When using functions, always use `( )`.

# %%
lst = [20,30,40]
sum(lst)
# Out:
# 90

# %% [markdown]
# Using the function `len` to determine the number of elements.

# %%
len(lst)
# Out:
# 3

# %% [markdown]
# The output of a function can also be assigned to a variable.

# %%
listlen = len(lst)
print(listlen)
# Out:
# 3

# %%
# Exercise
# compute the average of lst using the functions above only
average = sum(lst) / len(lst)
print(average)
# Out:
# 30.0
