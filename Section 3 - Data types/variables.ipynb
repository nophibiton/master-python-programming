# %%
a = 4
b = 3
c = 7
print(a)
print(b)
# Out:
# 4
# 3

# %%
print(c)
# Out:
# 7

# %% [markdown]
# In making string, python does not differentiate between single and double quotes.

# %%
d = 'Hello'
e = "Nophi likes purple"
print(d,e)
print(a,b,c)
# Out:
# Hello Nophi likes purple
# 4 3 7

# %% [markdown]
# *   Multiple strings or characters can be
# used a variable as long as it is not a reserved keyword.
# *   Varibale names cannot start with a number.
#
# *   Only the underscore '_' special character can be used for variable name.
#
# *   The '#' is a python keyword for comments which means anything after it on the same line will be ignored by python.
#
# *   The shotcut key for comment is CTRL + ?

# %%
# comment. Python will ignore this line  
filter_Order = 2048 # comment after the code
data2plot = 3

# %%
# mutiple assignments
f,g = 10,20
print(f,g)
# Out:
# 10 20

# %% [markdown]
# In order to remember or show all the variables that were created, use th `%whos` command.

# %%
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20

# %%
# Exercise:
# 1) can you over-write a variable in the same type
# 2) can you over-write a variable using a different data type

# %%
# let value of x
x = 1

# %%
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# x              int     1

# %%
# change value of variable x
x = 2

# check whether value has changed
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# x              int     2

# %% [markdown]
# Yes you can change variable value for int

# %%
# try for string
name = 'nophi'

# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# name           str     nophi
# x              int     2

# %%
# change the value of name
name = 'ian'

# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# name           str     ian
# x              int     2

# %% [markdown]
# Yes, the value of the variable with type string can be changed.

# %%
# changing the data type
x = 'Nophi'
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# name           str     ian
# x              str     Nophi

# %% [markdown]
# Yes, the variable type can be changed from int to string.

# %%
# changing data type from string to int
x = 23
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# name           str     ian
# x              int     23

# %% [markdown]
# Yes, the variable data type can be change from string to int.

# %%
# deleting a variable
del a

# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# b              int     3
# c              int     7
# d              str     Hello
# data2plot      int     3
# e              str     Nophi likes purple
# f              int     10
# filterOrder    int     2048
# filter_Order   int     2048
# g              int     20
# name           str     ian
# x              int     2
