# %%
x = 7
y = 4.1
z = 0

# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# x          int      7
# y          float    4.1
# z          int      0

# %%
print(x-6)
c = x + y - 2
print(c)
# Out:
# 1
# 9.1

# %% [markdown]
# *   The symbol `*` is used for multiplication.
# *   The forward slash `/` is used for division.
#
#
# *   The back slash `\` is not used for math operation but as 'next line' command. This is simillar to `...` of Matlab.

# %%
# floating-point algebra vs 'real' algebra
print(x*y)

4/ 3
# Out:
# 28.699999999999996
# 1.3333333333333333

# %%
# power
3**2 # this is 3^2
# Out:
# 9

# %% [markdown]
# Use PEMDAS for the sequence of operation.

# %%
# to get the square root
9**(1/2)
# Out:
# 3.0

# %%
firstName = 'Nophi'
lastName = 'Biton'

#overloading the plus sign is used in another way 
print(firstName+' '+lastName)
# Out:
# Nophi Biton

# %%
firstName - lastName #not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b71644a8a2ba> in <module>()
# ----> 1 firstName - lastName #not allowed
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
firstName*2 # another example of overloading
# Out:
# 'NophiNophi'

# %%
# Exercise
# Is dividing string a meaningful operation
firstName / 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-7471ba7374f5> in <module>()
#       1 # Exercise
#       2 # Is dividing string a meaningful operation
# ----> 3 firstName / 2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# Dividing string is not a meaningful operation.
