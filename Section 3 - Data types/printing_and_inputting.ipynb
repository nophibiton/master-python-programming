# %%
x = 3
y = 5

print ('3 times 5 equals 15')
print (str(x) + ' times '+ str(y) + ' equals ' + str(x*y))
# Out:
# 3 times 5 equals 15
# 3 times 5 equals 15

# %% [markdown]
# *   When using the `input` function, you always get a string.

# %%
ans = input('Feed me a stray cat. ')

ans = float(ans)

type(ans)
# Out:
# Feed me a stray cat. 3.1
# float

# %% [markdown]
# Note the Pythagorean Theorem is:
# $a^2 + b^2 = c^2$

# %%
# Exercise
# Pythagorean theorem: a**2 + b**2 = c**2
# get two numbers from the user: a, b
# compute and print the length of side c
a = float(input('Enter the value of a: '))
b = float(input('Enter the value of b: '))
c = ((a)**2 +(b)**2)**(1/2)

print(f"The value of c is {c}.")
# Out:
# Enter the value of a: 3
# Enter the value of b: 4
# The value of c is 5.0.
