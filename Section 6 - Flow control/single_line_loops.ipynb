# %%
# reminder
import random

#if random.randint(1,10) > 5: print('This is a large number.')

print('This number is small') if random.randint(1,10)<5 else print('This is a large number.')
# Out:
# This number is small

# %%
for i in range(0,10):
  print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
[print(i**2) for i in range(0,10)]
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# [None, None, None, None, None, None, None, None, None, None]

# %%
a = print('s')
type(a)
# Out:
# s
# NoneType

# %%
# list comprehension

n = [i**2-i**(1/2) for i in range(0,10) if i>5]
n
# Out:
# [33.55051025721682, 46.35424868893541, 61.17157287525381, 78.0]

# %%
# Exercise
#
#

text = ['Promising','Yves', 'that','home','on','Nobb']

[print(word[0]) for word in text];
# Out:
# P
# Y
# t
# h
# o
# N

# %%
# convert range to list

newlist = ['']*10

#for i in range(10):
#  if i%2 == 1:
#    newlist[i] = 'Odd'
#  else:
#    newlist[i] = i

#newlist

newlist = ['Odd' if i%2==1 else i for i in range(0,10)]
newlist
# Out:
# [0, 'Odd', 2, 'Odd', 4, 'Odd', 6, 'Odd', 8, 'Odd']

# %%
import numpy as np

x1 = np.linspace(-3,3,11)
y1 = x1**2

print(x1)
print(y1)
print(' ')

x2 = [i/(5/3) for i in range(-5,6)]
y2 = [x2[i]**2 for i in range(0,len(x2))]
y3 = [i**2 for i in x2]
print(x2)
print(y2)
print(y3)
# Out:
# [-3.  -2.4 -1.8 -1.2 -0.6  0.   0.6  1.2  1.8  2.4  3. ]
# [9.   5.76 3.24 1.44 0.36 0.   0.36 1.44 3.24 5.76 9.  ]
#
# [-3.0, -2.4, -1.7999999999999998, -1.2, -0.6, 0.0, 0.6, 1.2, 1.7999999999999998, 2.4, 3.0]
# [9.0, 5.76, 3.2399999999999993, 1.44, 0.36, 0.0, 0.36, 1.44, 3.2399999999999993, 5.76, 9.0]
# [9.0, 5.76, 3.2399999999999993, 1.44, 0.36, 0.0, 0.36, 1.44, 3.2399999999999993, 5.76, 9.0]

# %%
# Out:
# None
