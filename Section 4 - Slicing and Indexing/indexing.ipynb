# %%
# indexing 
arange = range(10,15)
arange
# Out:
# range(10, 15)

# %%
alist = list(arange)
alist
# Out:
# [10, 11, 12, 13, 14]

# %%
alist[1]

alist = [54,1,4,546,-45,0,2,4,4]
print(alist[5])
print(alist[-1])
print(alist[-3])
# Out:
# 0
# 4
# 2
