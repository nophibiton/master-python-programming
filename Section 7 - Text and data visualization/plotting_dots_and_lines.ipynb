# %%
from matplotlib.lines import MarkerStyle
import matplotlib.pyplot as plt


plt.plot(3,4,'o')
plt.plot(2,4,'s')
plt.show()

plt.plot(31,41,'o')
plt.plot(122,43,'s')
plt.show()

# %%
plt.plot(3,2,'ro',label='red circle')
plt.plot(3,4,'bp',label='blue pentagon')
plt.legend()
plt.show()

# %%
x = [0,1]
y = [0,2]
plt.plot(x,y,'r')
plt.plot([0,0],[1,2],'g')
plt.legend(['red line','gree line'])
plt.show()

# %%
import numpy as np

x = np.linspace(0,3*np.pi,123)
y = np.sin(x)

plt.plot(x,y,'k.')
plt.show()

# %%
# Exercise 
# Draw your favorite letter
#

height = 5
width = 2.5

stroke1x = [1,1]
stroke1y = [1,height]

stroke2x = [1,width]
stroke2y = [height,1]

stroke3x = [width,width]
stroke3y = [1,height]

plt.plot(stroke1x,stroke1y,'r',linewidth=7.0)
plt.plot(stroke2x,stroke2y,'b',linewidth=7.0)
plt.plot(stroke3x,stroke3y,'y',linewidth=7.0)
plt.axis('square')
plt.show()
